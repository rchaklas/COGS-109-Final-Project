# %%
#the usuals
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#imports for 1
from scipy import linalg
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Basic Stats

# %%
Basic_Stats=pd.read_csv('Basic_Stats.csv')
Basic_Stats.head()
# Out:
#     Age        Birth Place    Birthday           College Current Status  \
# 0   NaN  Grand Rapids , MI   5/23/1921        Notre Dame        Retired
# 1   NaN        Dayton , OH  12/21/1930            Dayton        Retired
# 2  56.0        Temple , TX   9/11/1960    Louisiana Tech        Retired
# 3  30.0   New Orleans , LA   9/30/1986               LSU        Retired
# 4  25.0       Detroit , MI   3/31/1992  Central Michigan         Active
#
#           Current Team  Experience  Height (inches)     High School  \
# 0                  NaN   3 Seasons             71.0             NaN
# 1                  NaN    1 Season             70.0             NaN
# 2                  NaN    1 Season             74.0             NaN
# 3                  NaN   5 Seasons             73.0             NaN
# 4  Pittsburgh Steelers  3rd season             77.0  Clintondale HS
#
#           High School Location            Name  Number            Player Id  \
# ...

# %% [markdown]
# # Career_Stats_Defensive

# %%
Career_Stat_Def=pd.read_csv('Career_Stats_Defensive.csv')
Career_Stat_Def.head()
# Out:
#             Player Id            Name Position  Year               Team  \
# 0  quinnjohnson/79593  Johnson, Quinn      NaN  2013   Tennessee Titans
# 1  quinnjohnson/79593  Johnson, Quinn      NaN  2012   Tennessee Titans
# 2  quinnjohnson/79593  Johnson, Quinn      NaN  2011   Tennessee Titans
# 3  quinnjohnson/79593  Johnson, Quinn      NaN  2011     Denver Broncos
# 4  quinnjohnson/79593  Johnson, Quinn      NaN  2010  Green Bay Packers
#
#    Games Played Total Tackles Solo Tackles Assisted Tackles Sacks Safties  \
# 0             4             0           --               --    --      --
# 1            16             1            1                0   0.0      --
# 2             4             0           --               --    --      --
# 3             0             0           --               --    --      --
# 4            11             4            4                0   0.0      --
#
#   Passes Defended Ints Ints for TDs Int Yards  Yards Per Int  \
# ...

# %% [markdown]
# # Career_Stats_Field_Goal_Kickers

# %%
Career_Stat_Kick=pd.read_csv('Career_Stats_Field_Goal_Kickers.csv')
Career_Stat_Kick.head()
# Out:
#               Player Id            Name Position  Year                Team  \
# 0      jeffhall/2500970      Hall, Jeff      NaN  2000      St. Louis Rams
# 1  benagajanian/2508255  Agajanian, Ben      NaN  1964  San Diego Chargers
# 2  benagajanian/2508255  Agajanian, Ben      NaN  1962     Oakland Raiders
# 3  benagajanian/2508255  Agajanian, Ben      NaN  1961   Green Bay Packers
# 4  benagajanian/2508255  Agajanian, Ben      NaN  1961       Dallas Texans
#
#    Games Played Kicks Blocked Longest FG Made FGs Made FGs Attempted  ...  \
# 0             3             0              50        4             5  ...
# 1             3             0              --        2             4  ...
# 2             6             0              --        5            14  ...
# 3             3             0              --        1             2  ...
# 4             3             0              --        3             9  ...
#
# ...

# %% [markdown]
# # Career_Stats_Fumbles

# %%
Career_Stat_Fumb=pd.read_csv('Career_Stats_Fumbles.csv')
Career_Stat_Fumb.head()
# Out:
#                 Player Id              Name Position  Year  \
# 0        joeadams/2532782        Adams, Joe      NaN  2012
# 1  clarenceverdin/2503464  Verdin, Clarence      NaN  1994
# 2  clarenceverdin/2503464  Verdin, Clarence      NaN  1993
# 3  clarenceverdin/2503464  Verdin, Clarence      NaN  1992
# 4  clarenceverdin/2503464  Verdin, Clarence      NaN  1991
#
#                  Team  Games Played Fumbles Fumbles Lost Forced Fumbles  \
# 0   Carolina Panthers             9       4            3             --
# 1     Atlanta Falcons            12       3            1             --
# 2  Indianapolis Colts            16       3            2             --
# 3  Indianapolis Colts            16       2            1             --
# 4  Indianapolis Colts            16       2            0              0
#
#   Own Fumbles Recovered Opponent Fumbles Recovered Own Fumble Return Yards  \
# 0                     1                         --                       0
# ...

# %% [markdown]
# # Career_Stats_Kick_Return

# %%
Career_Stat_Return=pd.read_csv('Career_Stats_Kick_Return.csv')
Career_Stat_Return.head()
# Out:
#              Player Id           Name Position  Year                  Team  \
# 0  bobbyfowler/2514295  Fowler, Bobby      NaN  1985    New Orleans Saints
# 1    tomfarris/2513861    Farris, Tom      NaN  1948       Chicago Rockets
# 2    tomfarris/2513861    Farris, Tom      NaN  1947         Chicago Bears
# 3    tomfarris/2513861    Farris, Tom      NaN  1946         Chicago Bears
# 4   johntanner/2527011   Tanner, John      NaN  1974  New England Patriots
#
#    Games Played Returns Yards Returned Yards Per Return Longest Return  \
# 0            10       4             78             19.5             23
# 1             0      --             --               --             --
# 2             9      --             --               --             --
# 3            11       1             27             27.0             --
# 4            13       2             17              8.5             --
#
#   Returns for TDs Returns Longer than 20 Yards Returns Longer than 40 Yards  \
# ...

# %% [markdown]
# # Career_Stats_Kickoff

# %%
Career_Stat_KickOff=pd.read_csv('Career_Stats_Kickoff.csv')
Career_Stat_KickOff.head()
# Out:
#             Player Id          Name Position  Year               Team  \
# 0  jasonbaker/2504395  Baker, Jason      NaN  2011  Carolina Panthers
# 1  jasonbaker/2504395  Baker, Jason      NaN  2010  Carolina Panthers
# 2  jasonbaker/2504395  Baker, Jason      NaN  2009  Carolina Panthers
# 3  jasonbaker/2504395  Baker, Jason      NaN  2008  Carolina Panthers
# 4  jasonbaker/2504395  Baker, Jason      NaN  2007  Carolina Panthers
#
#    Games Played Kickoffs Kickoff Yards Out of Bounds Kickoffs  \
# 0            16       --            --                     --
# 1            16       --            --                     --
# 2            16       --            --                     --
# 3            16       --            --                     --
# 4            16        7           453                      1
#
#   Yards Per Kickoff Touchbacks Touchback Percentage Kickoffs Returned  \
# 0                --         --                   --                --
# ...

# %% [markdown]
# # Career_Stats_Offensive_Line

# %%
Career_Stat_OffLine=pd.read_csv('Career_Stats_Offensive_Line.csv')
Career_Stat_OffLine.head()
# Out:
#                  Player Id               Name Position  Year  \
# 0         jimraiff/2523700         Raiff, Jim      NaN  1954
# 1        rosspetty/2523136        Petty, Ross      NaN  1920
# 2      billschuler/2525128      Schuler, Bill      NaN  1948
# 3      billschuler/2525128      Schuler, Bill      NaN  1947
# 4  georgesergienko/2525335  Sergienko, George      NaN  1946
#
#                Team  Games Played Games Started
# 0   Baltimore Colts             3            --
# 1   Decatur Staleys            10            --
# 2   New York Giants            12            --
# 3   New York Giants            11            --
# 4  Brooklyn Dodgers             0            --

# %% [markdown]
# # Career_Stats_Passing

# %%
Career_Stat_Pass=pd.read_csv('Career_Stats_Passing.csv')
Career_Stat_Pass.head()
# Out:
#             Player Id          Name Position  Year             Team  \
# 0   tomfarris/2513861   Farris, Tom      NaN  1948  Chicago Rockets
# 1   tomfarris/2513861   Farris, Tom      NaN  1947    Chicago Bears
# 2   tomfarris/2513861   Farris, Tom      NaN  1946    Chicago Bears
# 3  billdemory/2512778  Demory, Bill      NaN  1974    New York Jets
# 4  billdemory/2512778  Demory, Bill      NaN  1973    New York Jets
#
#    Games Played Passes Attempted Passes Completed Completion Percentage  \
# 0             0               --               --                    --
# 1             9                2                0                   0.0
# 2            11               21                8                  38.1
# 3             1               --               --                    --
# 4             6               39               12                  30.8
#
#    Pass Attempts Per Game  ... TD Passes Percentage of TDs per Attempts Ints  \
# ...

# %% [markdown]
# # Career_Stats_Punt_Return

# %%
Career_Stat_PuntRe=pd.read_csv('Career_Stats_Punt_Return.csv')
Career_Stat_PuntRe.head()
# Out:
#            Player Id         Name Position  Year              Team  \
# 0  fredevans/2513736  Evans, Fred      NaN  1948     Chicago Bears
# 1  fredevans/2513736  Evans, Fred      NaN  1948   Chicago Rockets
# 2  fredevans/2513736  Evans, Fred      NaN  1947   Chicago Rockets
# 3  fredevans/2513736  Evans, Fred      NaN  1947     Buffalo Bills
# 4  fredevans/2513736  Evans, Fred      NaN  1946  Cleveland Browns
#
#    Games Played Returns Yards Returned Yards Per Return Longest Return  \
# 0             3       1             15             15.0             --
# 1             0      --             --               --             --
# 2             0      --             --               --             --
# 3             0      --             --               --             --
# 4             0      --             --               --             --
#
#   Returns for TDs Returns Longer than 20 Yards Returns Longer than 40 Yards  \
# ...

# %% [markdown]
# # Career_Stats_Punting

# %%
Career_Stat_Punting=pd.read_csv('Career_Stats_Punting.csv')
Career_Stat_Punting.head()
# Out:
#             Player Id          Name Position  Year                 Team  \
# 0   davebaker/2508869   Baker, Dave      NaN  1961  San Francisco 49ers
# 1   davebaker/2508869   Baker, Dave      NaN  1960  San Francisco 49ers
# 2   davebaker/2508869   Baker, Dave      NaN  1959  San Francisco 49ers
# 3  jasonbaker/2504395  Baker, Jason      NaN  2011    Carolina Panthers
# 4  jasonbaker/2504395  Baker, Jason      NaN  2010    Carolina Panthers
#
#    Games Played Punts Gross Punting Yards Net Punting Yards Longest Punt  ...  \
# 0            14    --                  --                --           --  ...
# 1            12     3                 143                --           --  ...
# 2            12    --                  --                --           --  ...
# 3            16    66               2,819             2,253           56  ...
# 4            16    95               4,097             3,469           60  ...
#
# ...

# %% [markdown]
# # Career_Stats_Receiving

# %%
Career_Stat_Receiving=pd.read_csv('Career_Stats_Receiving.csv')
Career_Stat_Receiving.head()
# Out:
#            Player Id         Name Position  Year              Team  \
# 0  fredevans/2513736  Evans, Fred      NaN  1948     Chicago Bears
# 1  fredevans/2513736  Evans, Fred      NaN  1948   Chicago Rockets
# 2  fredevans/2513736  Evans, Fred      NaN  1947   Chicago Rockets
# 3  fredevans/2513736  Evans, Fred      NaN  1947     Buffalo Bills
# 4  fredevans/2513736  Evans, Fred      NaN  1946  Cleveland Browns
#
#    Games Played Receptions Receiving Yards Yards Per Reception  \
# 0             3          1              -2                -2.0
# 1             0         --              --                  --
# 2             0         --              --                  --
# 3             0         --              --                  --
# 4             0         --              --                  --
#
#    Yards Per Game Longest Reception Receiving TDs  \
# 0            -0.7                --             0
# 1             0.0                --            --
# ...

# %% [markdown]
# # Career_Stats_Rushing

# %%
Career_Stat_Rushing=pd.read_csv('Career_Stats_Rushing.csv')
Career_Stat_Rushing.head()
# Out:
#            Player Id         Name Position  Year              Team  \
# 0  fredevans/2513736  Evans, Fred      NaN  1948     Chicago Bears
# 1  fredevans/2513736  Evans, Fred      NaN  1948   Chicago Rockets
# 2  fredevans/2513736  Evans, Fred      NaN  1947   Chicago Rockets
# 3  fredevans/2513736  Evans, Fred      NaN  1947     Buffalo Bills
# 4  fredevans/2513736  Evans, Fred      NaN  1946  Cleveland Browns
#
#    Games Played Rushing Attempts  Rushing Attempts Per Game Rushing Yards  \
# 0             3               10                        3.3            15
# 1             0               --                        0.0            --
# 2             0               --                        0.0            --
# 3             0               --                        0.0            --
# 4             0               --                        0.0            --
#
#   Yards Per Carry Rushing Yards Per Game Rushing TDs Longest Rushing Run  \
# ...

# %% [markdown]
# # Game_Logs_Defensive_Lineman

# %%
Career_Stat_Game_Log=pd.read_csv('Game_Logs_Defensive_Lineman.csv')
Career_Stat_Game_Log.head()
# Out:
#             Player Id          Name Position  Year          Season  Week  \
# 0  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     1
# 1  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     2
# 2  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     3
# 3  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     4
# 4  l.t.walton/2552444  Walton, L.T.       DE  2016  Regular Season     1
#
#   Game Date Home or Away Opponent Outcome  ... Assisted Tackles  Sacks  \
# 0     08/12         Home      DET       L  ...                0    0.0
# 1     08/18         Home      PHI       L  ...               --     --
# 2     08/26         Away       NO       W  ...               --     --
# 3     09/01         Away      CAR       L  ...                3    0.0
# 4     09/12         Away      WAS       W  ...               --     --
#
#   Safties Passes Defended Ints Int Yards Yards Per Int Longest Int Return  \
# ...
